# %% [markdown]
# ## Group By function
# ### SUM , MIN , MAX , Count, mean

# %%
import pandas as pd
import seaborn as sb
import numpy as np

# %%
import os

# %%
os.chdir('C:\\jupyterfiles\\data')

# %%
pup = pd.read_csv('pupils.csv')

# %%
titanic = sb.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pup.min(numeric_only=True)
# Out:
# Age          6
# Height      90
# Weight      26
# avg         64
# income    7600
# rooms        2
# family       3
# type         1
# dtype: int64

# %%
type(pup.min())
# Out:
# pandas.core.series.Series

# %%
pup.mean(numeric_only=True)
# Out:
# Age           9.433333
# Height      137.266667
# Weight       51.500000
# avg          80.500000
# income    20096.666667
# rooms         4.366667
# family        5.833333
# type          1.833333
# dtype: float64

# %%
pup.query('Age<10').mean(numeric_only=True)
# Out:
# Age           7.823529
# Height      134.647059
# Weight       49.529412
# avg          79.470588
# income    17200.000000
# rooms         4.352941
# family        5.823529
# type          1.764706
# dtype: float64

# %%
pup.query('Age<10').mean(numeric_only=True).to_frame('mean')
# Out:
#                 mean
# Age         7.823529
# Height    134.647059
# Weight     49.529412
# avg        79.470588
# income  17200.000000
# rooms       4.352941
# family      5.823529
# type        1.764706

# %%
pup['income'].mean()
# Out:
# 20096.666666666668

# %%
pup['income'].std()
# Out:
# 11943.270600789307

# %%
pup
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0      adar    6      SP     113      30   70   16700      7       6     1   M
# 1      agam    6      GR     172      71   92    9200      5       4     2   F
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 3      dani    7      US     160      70   90   15000      4       4     2   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 5     efrat    7      EN     115      33   75    8000      5       5     3   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 7       eli    8      GR     155      61   84    8900      7      10     2   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 10   itamar    8      EN     110      30   71   27000      2       5     2   M
# ...

# %%
# mean income
# age > 10
#rooms > 5

# %%
pup.query('Age > 10 and rooms > 5')['income'].mean()
# Out:
# 22950.0

# %%
pup.rooms.value_counts()
# Out:
# rooms
# 5    7
# 4    6
# 2    6
# 6    5
# 7    3
# 3    3
# Name: count, dtype: int64

# %%
# Group by
titanic.groupby('sex').ngroups
# Out:
# 2

# %%
titanic.groupby('sex').get_group('male')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.groupby('sex')['survived'].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
pup.groupby('Country')['income'].mean()
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
pup.groupby('Country').first()
# Out:
#           Name  Age  Height  Weight  avg  income  rooms  family  type gen
# Country
# EN       efrat    7     115      33   75    8000      5       5     3   F
# FR       talya   12     167      67   89   10900      6       6     2   F
# GR        agam    6     172      71   92    9200      5       4     2   F
# ISR        avi    7     143      58   82   12000      3       7     1   M
# SP        adar    6     113      30   70   16700      7       6     1   M
# US        dani    7     160      70   90   15000      4       4     2   M

# %%
df_sort = pup.sort_values('income')

# %%
df_sort.groupby('Country').first()
# Out:
#             Name  Age  Height  Weight  avg  income  rooms  family  type gen
# Country
# EN         efrat    7     115      33   75    8000      5       5     3   F
# FR         talya   12     167      67   89   10900      6       6     2   F
# GR           eli    8     155      61   84    8900      7      10     2   M
# ISR      evyatar    8     110      34   72    7600      3       4     1   M
# SP          ofer   10     110      34   71    9300      4       8     1   M
# US          dani    7     160      70   90   15000      4       4     2   M

# %%
pup.groupby('Country')[['income' , 'Age']].mean()
# Out:
#           income    Age
# Country
# EN       20575.0   9.75
# FR       25925.0  12.50
# GR       18225.0   8.00
# ISR      18900.0   8.70
# SP       16550.0   9.75
# US       22200.0   9.00

# %%
pup.groupby('Country').groups.keys()
# Out:
# dict_keys(['EN', 'FR', 'GR', 'ISR', 'SP', 'US'])

# %%
pup.groupby('Age').groups.keys()
# Out:
# dict_keys([6, 7, 8, 9, 10, 11, 12, 13, 14])

# %%
pup.groupby('Country')[['income' , 'Age']].mean().rename(columns={'income': 'Parents Income','Age':'Child Age'})
# Out:
#          Parents Income  Child Age
# Country
# EN              20575.0       9.75
# FR              25925.0      12.50
# GR              18225.0       8.00
# ISR             18900.0       8.70
# SP              16550.0       9.75
# US              22200.0       9.00

# %%
a = pup.groupby('Country')

# %%
pup.corr(numeric_only=True)
# Out:
#              Age    Height    Weight       avg    income     rooms    family  \
# Age     1.000000  0.074586  0.118616  0.150426  0.344763  0.040584 -0.052251
# Height  0.074586  1.000000  0.974416  0.944887  0.079537  0.006496 -0.060690
# Weight  0.118616  0.974416  1.000000  0.959074  0.091562 -0.084762 -0.125074
# avg     0.150426  0.944887  0.959074  1.000000  0.145275 -0.065290 -0.212886
# income  0.344763  0.079537  0.091562  0.145275  1.000000  0.062980 -0.241287
# rooms   0.040584  0.006496 -0.084762 -0.065290  0.062980  1.000000  0.289322
# family -0.052251 -0.060690 -0.125074 -0.212886 -0.241287  0.289322  1.000000
# type    0.152952 -0.056107 -0.065094  0.075489  0.360018  0.173446 -0.043478
#
#             type
# Age     0.152952
# Height -0.056107
# Weight -0.065094
# avg     0.075489
# income  0.360018
# rooms   0.173446
# family -0.043478
# type    1.000000

# %%
c = (titanic.corr(numeric_only=True))

# %%
c
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
c.loc['survived']
# Out:
# survived      1.000000
# pclass       -0.338481
# age          -0.077221
# sibsp        -0.035322
# parch         0.081629
# fare          0.257307
# adult_male   -0.557080
# alone        -0.203367
# Name: survived, dtype: float64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#agg
x = pup.groupby('Country').agg(countbla_name = ('Name' , 'count')
                           ,mean_income = ('income','mean')
                           ,max_age =('Age' , 'max') )

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame
